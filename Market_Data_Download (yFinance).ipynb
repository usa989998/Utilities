# %% [markdown]
# ### yfinance download
#
# This code depends upon yfinance Python library. Please do ensure that you have it installed.
#
# pip install yfinance
#
# Other library is yliveticker
#
# pip install yliveticker
#
# import yliveticker
# yliveticker.YLiveTicker(on_ticker=on_new_msg, ticker_names=[
#     "BTC=X", "^GSPC", "^DJI", "^IXIC", "^RUT", "CL=F", "GC=F", "SI=F", "EURUSD=X", "^TNX", "^VIX", "GBPUSD=X", "JPY=X", "BTC-USD", "^CMC200", "^FTSE", "^N225"])

# %%
import yfinance as yf

#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2020-11-01', end='2020-12-31')

#see your data
tickerDf
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2020-11-02  203.756540  204.743960  199.597430  201.801666  30842200
# 2020-11-03  203.357600  207.576550  202.589606  205.890961  27512000
# 2020-11-04  213.461145  217.749919  211.865317  215.824951  42311800
# 2020-11-05  221.460204  223.534774  220.572528  222.706940  36080100
# 2020-11-06  221.679624  223.774147  217.460674  223.135818  25231900
# 2020-11-09  223.853938  227.524321  217.311070  217.819733  44395000
# 2020-11-10  213.939892  215.934669  209.172375  210.459000  44045100
# 2020-11-11  211.835402  217.470642  211.645896  215.984543  29440800
# 2020-11-12  216.642824  218.537856  213.900005  214.877441  21593900
# 2020-11-13  215.795039  216.852269  213.600787  215.944641  18621100
# 2020-11-16  214.308927  217.171444  213.959850  216.662766  24953300
# 2020-11-17  215.535726  217.111587  213.520997  213.900009  24154100
# ...

# %%
print (type(tickerDf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#info on the company
tickerData.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...

# %% [markdown]
# ### Information About Upcoming events

# %%
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get event data for ticker
tickerData.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-01-27 00:00:00  2021-02-01 00:00:00
# Earnings Average                 1.64                 1.64
# Earnings Low                     1.57                 1.57
# Earnings High                    1.86                 1.86
# Revenue Average           40202900000          40202900000
# Revenue Low               39888000000          39888000000
# Revenue High              41145000000          41145000000

# %% [markdown]
# ### Information About Analyst Recommendations

# %%
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get recommendation data for ticker
tickerData.recommendations
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2020-10-28 12:00:17  Morgan Stanley     Overweight              main
# 2020-10-28 13:22:56   Credit Suisse     Outperform              main
# 2020-10-29 16:00:20   Deutsche Bank            Buy              main
# 2020-11-05 10:48:37     Oppenheimer     Outperform    Perform     up
# 2020-11-24 11:17:51         KeyBanc     Overweight              init
#
# [299 rows x 4 columns]

# %%
tickerData.dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    3.08
# 2005-02-15    0.08
#               ...
# 2019-11-20    0.51
# 2020-02-19    0.51
# 2020-05-20    0.51
# 2020-08-19    0.51
# 2020-11-18    0.56
# Name: Dividends, Length: 68, dtype: float64

# %% [markdown]
# ### Institutional Holdings Information

# %%
tickerData.get_mutualfund_holders()
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  216122519    2020-06-29
# 1                            Vanguard 500 Index Fund  157336983    2020-06-29
# 2                             SPDR S&P 500 ETF Trust   77552110    2020-10-30
# 3        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   67754501    2020-10-30
# 4                            Fidelity 500 Index Fund   67731669    2020-08-30
# 5  Vanguard Institutional Index Fund-Institutiona...   66549216    2020-06-29
# 6                         Vanguard Growth Index Fund   59897952    2020-06-29
# 7                           iShares Core S&P 500 ETF   58109066    2020-09-29
# 8                         Growth Fund Of America Inc   53569352    2020-09-29
# 9                            Fidelity Contrafund Inc   37118078    2020-07-30
#
#     % Out        Value
# 0  0.0286  43983093841
# 1  0.0208  32019649410
# 2  0.0103  15701975711
# ...

# %%
tickerData.get_institutional_holders()
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  622689597    2020-09-29  0.0824
# 1                     Blackrock Inc.  516065148    2020-09-29  0.0683
# 2           State Street Corporation  309004107    2020-09-29  0.0409
# 3                           FMR, LLC  236747226    2020-09-29  0.0313
# 4      Price (T.Rowe) Associates Inc  180419808    2020-09-29  0.0239
# 5      Geode Capital Management, LLC  116538073    2020-09-29  0.0154
# 6            Capital World Investors  111872823    2020-09-29  0.0148
# 7    Capital International Investors   94601027    2020-09-29  0.0125
# 8  Capital Research Global Investors   94009486    2020-09-29  0.0124
# 9         Northern Trust Corporation   93421404    2020-09-29  0.0124
#
#           Value
# 0  130970302937
# 1  108543982578
# 2   64992833825
# 3   49795044044
# 4   37947698216
# 5   24511452894
# 6   23530210861
# 7   19897434008
# 8   19773015190
# 9   19649323903

# %%
tickerData.get_major_holders()
# Out:
#         0                                      1
# 0   0.06%        % of Shares Held by All Insider
# 1  71.91%       % of Shares Held by Institutions
# 2  71.95%        % of Float Held by Institutions
# 3    4872  Number of Institutions Holding Shares

# %%
tickerData.get_balance_sheet()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
tickerData.major_holders
# Out:
#         0                                      1
# 0   0.06%        % of Shares Held by All Insider
# 1  71.91%       % of Shares Held by Institutions
# 2  71.95%        % of Float Held by Institutions
# 3    4872  Number of Institutions Holding Shares

# %% [markdown]
# ### Download Higher Frequency Data (Intraday)

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "7d",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1m",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
#                              MSFT                                   AAPL  \
#                              Open    High     Low   Close Volume    Open
# Datetime
# 2020-11-18 04:15:00-05:00     NaN     NaN     NaN     NaN    NaN  119.40
# 2020-11-18 04:18:00-05:00     NaN     NaN     NaN     NaN    NaN  119.40
# 2020-11-18 04:20:00-05:00     NaN     NaN     NaN     NaN    NaN  119.50
# 2020-11-18 04:21:00-05:00     NaN     NaN     NaN     NaN    NaN  119.50
# 2020-11-18 04:22:00-05:00     NaN     NaN     NaN     NaN    NaN  119.56
# ...                           ...     ...     ...     ...    ...     ...
# 2020-11-27 16:54:00-05:00     NaN     NaN     NaN     NaN    NaN  116.48
# 2020-11-27 16:56:00-05:00  215.20  215.20  215.20  215.20    0.0  116.47
# 2020-11-27 16:58:00-05:00     NaN     NaN     NaN     NaN    NaN  116.48
# 2020-11-27 16:59:00-05:00  215.01  215.24  215.01  215.24    0.0     NaN
# 2020-11-27 17:00:00-05:00     NaN     NaN     NaN     NaN    NaN  116.50
#
#
# ...
